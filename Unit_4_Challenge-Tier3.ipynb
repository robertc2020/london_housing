# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %% [markdown]
# <span style="color:red">*RobertC: Let's inspect the dataframe and print some basic info.*</span>

# %%
properties.head(10)
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
# 5 1995-05-01        84409.1            53042.2      90258    63997.1
# 6 1995-06-01        94900.5            53700.3    90107.2    64252.3
# 7 1995-07-01         110128            52113.1    91441.2    63722.7
# 8 1995-08-01         112329            52232.2    92361.3    64432.6
# 9 1995-09-01         104473            51471.6    93273.1    64509.5
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# ...

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            305 non-null    datetime64[ns]
#  1   City of London        306 non-null    object
#  2   Barking & Dagenham    306 non-null    object
#  3   Barnet                306 non-null    object
#  4   Bexley                306 non-null    object
#  5   Brent                 306 non-null    object
#  6   Bromley               306 non-null    object
#  7   Camden                306 non-null    object
#  8   Croydon               306 non-null    object
#  9   Ealing                306 non-null    object
#  10  Enfield               306 non-null    object
#  11  Greenwich             306 non-null    object
#  12  Hackney               306 non-null    object
#  13  Hammersmith & Fulham  306 non-null    object
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %% [markdown]
# <span style="color:red">*RobertC: A quick inspection above shows that 3 columns of the dataframe are empty (34, 37, 47), the first column contains the datetime index, and the first row contains non-numerical values (some sort of codes?).*
# </span>
#
# <span style="color:red">*RobertC: Let's read in the dataset again, this time ignoring the first row, setting the first column with the datetime type as the index column, and removing empty columns.*
# </span>

# %%
lon = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= 0, skiprows=[1]).dropna(axis=1,how='all')

# %%
lon.shape
# Out:
# (305, 45)

# %%
lon.head()
# Out:
#             City of London  Barking & Dagenham       Barnet       Bexley  \
# 1995-01-01     91448.98487         50460.22660  93284.51832  64958.09036
# 1995-02-01     82202.77314         51085.77983  93190.16963  64787.92069
# 1995-03-01     79120.70256         51268.96956  92247.52435  64367.49344
# 1995-04-01     77101.20804         53133.50526  90762.87492  64277.66881
# 1995-05-01     84409.14932         53042.24852  90258.00033  63997.13588
#
#                   Brent      Bromley       Camden      Croydon       Ealing  \
# 1995-01-01  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069
# 1995-02-01  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551
# 1995-03-01  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288
# 1995-04-01  72965.63094  81124.41227  120097.8990  68610.04641  82188.90498
# 1995-05-01  73704.04743  81542.61561  119929.2782  68844.91690  82077.05525
#
# ...

# %%
lon.tail()
# Out:
#             City of London  Barking & Dagenham       Barnet       Bexley  \
# 2020-01-01     747610.8749         303653.3951  518542.2536  334765.0582
# 2020-02-01     777640.0072         304265.1522  519121.2414  337759.6868
# 2020-03-01     844988.5066         304098.6397  527747.3696  339215.3198
# 2020-04-01     867840.6290         283139.4356  526552.5034  346839.5401
# 2020-05-01     899831.2060         295743.7580  532503.0431  339407.7607
#
#                   Brent      Bromley       Camden      Croydon       Ealing  \
# 2020-01-01  423160.8403  435532.4343  815512.4609  371226.7231  466490.6533
# 2020-02-01  467144.9146  435704.4473  825249.3994  371356.5277  465613.8462
# 2020-03-01  461397.5397  434624.8346  870106.8452  370871.5399  478565.2259
# 2020-04-01  494454.5203  443481.9234  870626.7601  386737.9308  502107.0739
# 2020-05-01  466573.6494  420036.0164  862208.9963  369790.7901  490595.9244
#
# ...

# %%
lon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 305 entries, 1995-01-01 to 2020-05-01
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City of London        305 non-null    float64
#  1   Barking & Dagenham    305 non-null    float64
#  2   Barnet                305 non-null    float64
#  3   Bexley                305 non-null    float64
#  4   Brent                 305 non-null    float64
#  5   Bromley               305 non-null    float64
#  6   Camden                305 non-null    float64
#  7   Croydon               305 non-null    float64
#  8   Ealing                305 non-null    float64
#  9   Enfield               305 non-null    float64
#  10  Greenwich             305 non-null    float64
#  11  Hackney               305 non-null    float64
#  12  Hammersmith & Fulham  305 non-null    float64
#  13  Haringey              305 non-null    float64
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %% [markdown]
# <span style="color:red">*RobertC: OK, all clean now. Rather than renaming the columns, we'll type all of them in capital letters, to have consistent naming in all the columns.*
# </span>

# %%
cols = [col.upper() for col in lon.columns]
lon.columns = cols
lon.head()
# Out:
#             CITY OF LONDON  BARKING & DAGENHAM       BARNET       BEXLEY  \
# 1995-01-01     91448.98487         50460.22660  93284.51832  64958.09036
# 1995-02-01     82202.77314         51085.77983  93190.16963  64787.92069
# 1995-03-01     79120.70256         51268.96956  92247.52435  64367.49344
# 1995-04-01     77101.20804         53133.50526  90762.87492  64277.66881
# 1995-05-01     84409.14932         53042.24852  90258.00033  63997.13588
#
#                   BRENT      BROMLEY       CAMDEN      CROYDON       EALING  \
# 1995-01-01  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069
# 1995-02-01  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551
# 1995-03-01  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288
# 1995-04-01  72965.63094  81124.41227  120097.8990  68610.04641  82188.90498
# 1995-05-01  73704.04743  81542.61561  119929.2782  68844.91690  82077.05525
#
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %% [markdown]
# <span style="color:red">*RobertC: We changed the index column to the one with the time stamp, so no melting is necessary to prepare the desired plots.*</span>

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %% [markdown]
# <span style="color:red">*RobertC: Yes, they are. See 3 cells above (cell [9]).* </span>

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %% [markdown]
# <span style="color:red"> *RobertC: Ups. That's a very good point! Turns out the empty columns I've noticed before where there for a reason. They separated the 32 London boroughs from Inner/Outer London areas, which on turn were separated from all the UK regions that were separated from the entire UK (all together 3 separator columns).*
# </span>
#
#
#
# <span style="color:red"> *RobertC: In fact, also the first column ("City of London") is not listed on the wikipedia page (compare the printout below with the first table at https://en.wikipedia.org/wiki/London_boroughs; toggle the "London borough "column to have them in the alphabetic order). It should probably be grouped together with the 'Inner London' and 'Outer London' columns.*
# </span>
#
#
#
#
# <span style="color:red"> *RobertC: In conclusion, we're only interested in columns 1-32 of the dataframe. Let's select them below with the "loc[]" method for futher studies.*</span>

# %%
cols
# Out:
# ['CITY OF LONDON',
#  'BARKING & DAGENHAM',
#  'BARNET',
#  'BEXLEY',
#  'BRENT',
#  'BROMLEY',
#  'CAMDEN',
#  'CROYDON',
#  'EALING',
#  'ENFIELD',
#  'GREENWICH',
#  'HACKNEY',
#  'HAMMERSMITH & FULHAM',
#  'HARINGEY',
#  'HARROW',
#  'HAVERING',
#  'HILLINGDON',
#  'HOUNSLOW',
#  'ISLINGTON',
#  'KENSINGTON & CHELSEA',
#  'KINGSTON UPON THAMES',
#  'LAMBETH',
#  'LEWISHAM',
#  'MERTON',
#  'NEWHAM',
#  'REDBRIDGE',
#  'RICHMOND UPON THAMES',
#  'SOUTHWARK',
#  'SUTTON',
#  'TOWER HAMLETS',
#  'WALTHAM FOREST',
#  'WANDSWORTH',
#  'WESTMINSTER',
#  'INNER LONDON',
#  'OUTER LONDON',
#  'NORTH EAST',
#  'NORTH WEST',
#  'YORKS & THE HUMBER',
#  'EAST MIDLANDS',
#  'WEST MIDLANDS',
#  'EAST OF ENGLAND',
#  'LONDON',
#  'SOUTH EAST',
#  'SOUTH WEST',
#  'ENGLAND']

# %%
lon = lon.iloc[:,1:33]
lon.head()
# Out:
#             BARKING & DAGENHAM       BARNET       BEXLEY        BRENT  \
# 1995-01-01         50460.22660  93284.51832  64958.09036  71306.56698
# 1995-02-01         51085.77983  93190.16963  64787.92069  72022.26197
# 1995-03-01         51268.96956  92247.52435  64367.49344  72015.76274
# 1995-04-01         53133.50526  90762.87492  64277.66881  72965.63094
# 1995-05-01         53042.24852  90258.00033  63997.13588  73704.04743
#
#                 BROMLEY       CAMDEN      CROYDON       EALING      ENFIELD  \
# 1995-01-01  81671.47692  120932.8881  69158.16225  79885.89069  72514.69096
# 1995-02-01  81657.55944  119508.8622  68951.09542  80897.06551  73155.19746
# 1995-03-01  81449.31143  120282.2131  68712.44341  81379.86288  72190.44144
# 1995-04-01  81124.41227  120097.8990  68610.04641  82188.90498  71442.92235
# 1995-05-01  81542.61561  119929.2782  68844.91690  82077.05525  70630.77955
#
#               GREENWICH  ...       MERTON       NEWHAM    REDBRIDGE  \
# ...

# %% [markdown]
# <span style="color:red"> RobertC: 32 rows, all as in the table on wiki. Perfect! </span>

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %% [markdown]
# <span style="color:red">*RobertC: It's OK. Let's go straight to the point. We'll plot all the 32 boroughs on one plot and pick the one with the highest average prices. As expected it's Kensington & Chelsea (see below).*</span>
#
#
# <span style="color:red">*RobertC: But hey, Kensington & Chelsea were having the highest prices cosistently throughout the years... And the question that we need to answer is which borough observed the highest price increase. So, rather than studying absolute numbers, we need to show the ratio of prices relative to the initial period. We'll do that in the cells below.*</span>
#
#
#
# <span style="color:red"> *RobertC: Btw. it's interesting to see price drops for most of the boroughs shortly after the 2009 crisis and a stagnation of prices and generally unstable situation during the Brexit process (which started around the summer of 2016).*</span>

# %%
lon.plot(figsize=(20,15))
plt.xlabel("Date", fontsize=25)
plt.ylabel("Price [GBP]", fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %% [markdown]
# <span style="color:red"> *RobertC: OK, let's do that. Let's plot prices as a function of the year. In the cell below, we extract the year from the index datetime format and save it in a new column called 'Year'. Then we change the row index to 'Year', group by that year, and within each group aggreate to get the mean value per year, then we plot the distributions.*</span>

# %%
lon_year = lon.copy()
lon_year['Year'] = pd.DatetimeIndex(lon_year.index).year
lon_year.set_index('Year',inplace=True)
lon_year.groupby('Year').agg('mean').plot(figsize=(20,15))
plt.xlabel("Date", fontsize=25)
plt.ylabel("Price [GBP]", fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <span style="color:red">*RobertC: That was for the sake of practicing. For the futher analysis, let's continue with the months though.*
# </span>

# %% [markdown]
# ### <span style="color:red"> Normalized distributinons </span>

# %% [markdown]
# <span style="color:red">*RobertC: As we said before, to find the borough that observed the highest rise in the prices over the two decades we need to normalize the distributions to the first period. In the plot below, we're normalizing the distributions to January 1995.* </span>

# %%
lon_norm = lon/lon.loc['1995-01-01']
lon_norm.head()
# Out:
#             BARKING & DAGENHAM    BARNET    BEXLEY     BRENT   BROMLEY  \
# 1995-01-01            1.000000  1.000000  1.000000  1.000000  1.000000
# 1995-02-01            1.012397  0.998989  0.997380  1.010037  0.999830
# 1995-03-01            1.016027  0.988884  0.990908  1.009946  0.997280
# 1995-04-01            1.052978  0.972968  0.989525  1.023267  0.993302
# 1995-05-01            1.051169  0.967556  0.985207  1.033622  0.998422
#
#               CAMDEN   CROYDON    EALING   ENFIELD  GREENWICH  ...    MERTON  \
# 1995-01-01  1.000000  1.000000  1.000000  1.000000   1.000000  ...  1.000000
# 1995-02-01  0.988225  0.997006  1.012658  1.008833   0.979024  ...  0.974560
# 1995-03-01  0.994620  0.993555  1.018701  0.995528   0.985196  ...  0.982833
# 1995-04-01  0.993095  0.992074  1.028829  0.985220   0.994023  ...  0.974655
# 1995-05-01  0.991701  0.995471  1.027429  0.974020   1.019468  ...  0.985420
#
# ...

# %%
lon_norm.plot(figsize=(20,15))
plt.xlabel("Date", fontsize=25)
plt.ylabel("Price ratio to January 1995", fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <span style="color:red">*RobertC:
#     The borough with the highest increase is Hackney, with the average prices being about 9 times higher than in the begining of 1995.* </span>
#
#
# <span style="color:red">*RobertC: Let's also normalize to the average price in the entire 1995, to make sure that the result is stable agains the montly price fluctuations. The plot below confirms the Hackney borough again, although this time Hackney's prices are pretty closely followed by the prices of other boroughs.*
# </span>

# %%
lon_norm_1995 = lon/(lon.loc['1995-01-01':'1996-01-01'].mean())
#lon_norm_1995.head()

# %%
lon_norm_1995.plot(figsize=(20,15))
plt.xlabel("Date", fontsize=25)
plt.ylabel("Price ratio to 1995", fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <span style="color:red">*RobertC: Since the plots above are generally quite busy (32 lines), below we plot the normalized distrubution for just one borough, Hackey, to make sure that we correctly interpreted the busy plots. As expected, Hackey corresponds to the curve with highest price increase.*</span>

# %%
lon_norm_1995['HACKNEY'].plot(figsize=(20,15))
plt.xlabel("Date", fontsize=25)
plt.ylabel("Price ratio to 1995", fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# <span style="color:red">*RobertC: Now we need to melt :-) Or better yet, let's use the unstack function on the lon_year dataframe.*
#
# </span>

# %%
lon_boro_year = lon_year.groupby('Year').agg('mean').unstack()
lon_boro_year.head(60)
# Out:
#                     Year
# BARKING & DAGENHAM  1995     51817.969390
#                     1996     51718.192690
#                     1997     55974.262309
#                     1998     60285.821083
#                     1999     65320.934441
#                     2000     77549.513290
#                     2001     88664.058223
#                     2002    112221.912482
#                     2003    142498.927800
#                     2004    158175.982483
#                     2005    163360.782017
#                     2006    167853.342558
#                     2007    184909.807383
#                     2008    187356.865783
#                     2009    156446.896358
#                     2010    166560.705275
#                     2011    163465.144225
#                     2012    165863.911600
#                     2013    173733.624933
#                     2014    201172.229417
#                     2015    233460.107425
#                     2016    273919.636042
# ...

# %% [markdown]
# <span style="color:red">*RobertC: Do we get the same values as in the very first plot, e.g. for 'KENSINGTON & CHELSEA' boro in the years 1995 and 2020?*
# </span>

# %%
print(lon_boro_year['KENSINGTON & CHELSEA'][1995]/10**6,lon_boro_year['KENSINGTON & CHELSEA'][2020]/10**6)
# Out:
# 0.19285726063333336 1.3372160238000002

# %% [markdown]
# <span style="color:red">*RobertC: Yes! OK, so now let's write the function.*
# </span>

# %%
def create_price_ratio(boro='KENSINGTON & CHELSEA',my_year=2018, relative_to = 1998, df = lon_year):
    df_by = df.groupby('Year').agg('mean').unstack()
    ratio = df_by[boro][my_year]/df_by[boro][relative_to]
    return ratio

# %% [markdown]
# <span style="color:red">*RobertC: A few examples of function call below:*
# </span>

# %%
create_price_ratio()
# Out:
# 5.082465066092464

# %%
create_price_ratio('HACKNEY',2020,1995)
# Out:
# 8.633086108475409

# %%
create_price_ratio('SOUTHWARK',2020,1995)
# Out:
# 7.901023064418229

# %%
create_price_ratio('HACKNEY',2020,2000)
# Out:
# 4.2944752608996835

# %%
create_price_ratio('SOUTHWARK',2020,2000)
# Out:
# 3.5687906111221563

# %% [markdown]
# <span style="color:red">*RobertC: Done! :-)*
# </span>

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# <span style="color:red">*RobertC: The conclusion of this study is that Hackney is the London borough that observered the highest price increase relative to 1995.*</span>
